# %%
# !pip install s3fs
# Out:
# Requirement already satisfied: s3fs in C:\Users\akans\AppData\Local\Programs\Python\Python313\Lib\site-packages (2026.4.0)
# Requirement already satisfied: aiobotocore<4.0.0,>=2.19.0 in C:\Users\akans\AppData\Local\Programs\Python\Python313\Lib\site-packages (from s3fs) (3.5.0)
# Requirement already satisfied: fsspec==2026.4.0 in C:\Users\akans\AppData\Local\Programs\Python\Python313\Lib\site-packages (from s3fs) (2026.4.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1,>=3.9.0 in C:\Users\akans\AppData\Local\Programs\Python\Python313\Lib\site-packages (from s3fs) (3.13.5)
# Requirement already satisfied: aioitertools<1.0.0,>=0.5.1 in C:\Users\akans\AppData\Local\Programs\Python\Python313\Lib\site-packages (from aiobotocore<4.0.0,>=2.19.0->s3fs) (0.13.0)
# Requirement already satisfied: botocore<1.42.92,>=1.42.90 in C:\Users\akans\AppData\Local\Programs\Python\Python313\Lib\site-packages (from aiobotocore<4.0.0,>=2.19.0->s3fs) (1.42.91)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in C:\Users\akans\AppData\Local\Programs\Python\Python313\Lib\site-packages (from aiobotocore<4.0.0,>=2.19.0->s3fs) (2.9.0.post0)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in C:\Users\akans\AppData\Local\Programs\Python\Python313\Lib\site-packages (from aiobotocore<4.0.0,>=2.19.0->s3fs) (1.1.0)
# Requirement already satisfied: multidict<7.0.0,>=6.0.0 in C:\Users\akans\AppData\Local\Programs\Python\Python313\Lib\site-packages (from aiobotocore<4.0.0,>=2.19.0->s3fs) (6.7.1)
# Requirement already satisfied: wrapt<3.0.0,>=1.10.10 in C:\Users\akans\AppData\Local\Programs\Python\Python313\Lib\site-packages (from aiobotocore<4.0.0,>=2.19.0->s3fs) (2.1.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in C:\Users\akans\AppData\Local\Programs\Python\Python313\Lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1,>=3.9.0->s3fs) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in C:\Users\akans\AppData\Local\Programs\Python\Python313\Lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1,>=3.9.0->s3fs) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in C:\Users\akans\AppData\Local\Programs\Python\Python313\Lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1,>=3.9.0->s3fs) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in C:\Users\akans\AppData\Local\Programs\Python\Python313\Lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1,>=3.9.0->s3fs) (1.8.0)
# Requirement already satisfied: propcache>=0.2.0 in C:\Users\akans\AppData\Local\Programs\Python\Python313\Lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1,>=3.9.0->s3fs) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in C:\Users\akans\AppData\Local\Programs\Python\Python313\Lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1,>=3.9.0->s3fs) (1.23.0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in C:\Users\akans\AppData\Local\Programs\Python\Python313\Lib\site-packages (from botocore<1.42.92,>=1.42.90->aiobotocore<4.0.0,>=2.19.0->s3fs) (2.6.3)
# Requirement already satisfied: six>=1.5 in C:\Users\akans\AppData\Local\Programs\Python\Python313\Lib\site-packages (from python-dateutil<3.0.0,>=2.1->aiobotocore<4.0.0,>=2.19.0->s3fs) (1.17.0)
# Requirement already satisfied: idna>=2.0 in C:\Users\akans\AppData\Local\Programs\Python\Python313\Lib\site-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1,>=3.9.0->s3fs) (3.13)
# [notice] A new release of pip is available: 26.0.1 -> 26.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from kafka import KafkaConsumer
from time import sleep
from json import dumps,loads
import json
from s3fs import S3FileSystem

# %%
consumer = KafkaConsumer(
    'demo_test1',
     bootstrap_servers=['13.201.36.135:9092'], 
    value_deserializer=lambda x: loads(x.decode('utf-8')),
    api_version=(3, 3, 1)
)

# %%
# for c in consumer:
 #   print(c.value)

# %%
s3 = S3FileSystem()

# %%
for count, i in enumerate(consumer):
    with s3.open("s3://kafka-stock-market-akansha/stock_market_{}.json".format(count), 'w') as file:
        json.dump(i.value, file)
